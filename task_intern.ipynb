# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\git-repos\interns_task\taskdata.csv")

# %%
df.head()
# Out:
#    user_id  account_id  max_return_days  average_return_days  \
# 0   410039       496.0                8             1.500000
# 1   410240       499.0               37             8.200000
# 2   411764       493.0                9             1.533333
# 3   411985       262.0                1             1.000000
# 4   412071       496.0                1             1.000000
#
#    customer_since_months  total_revenue  average_revenue  avg_vas_count  \
# 0                     14            0.0              0.0       3.666667
# 1                     10            0.0              0.0       4.900000
# 2                     15            0.0              0.0       5.333333
# 3                     14            0.0              0.0       6.307692
# 4                     18            0.0              0.0       5.846154
#
#    avg_used_vas_value  business_type  avg_wallet_bonus  avg_active_ads  \
# 0           66.666667              0             300.0       79.333333
# ...

# %%
df=df.astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4407 entries, 0 to 4406
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                4407 non-null   float32
#  1   account_id             4400 non-null   float32
#  2   max_return_days        4407 non-null   float32
#  3   average_return_days    4407 non-null   float32
#  4   customer_since_months  4407 non-null   float32
#  5   total_revenue          4407 non-null   float32
#  6   average_revenue        4407 non-null   float32
#  7   avg_vas_count          4407 non-null   float32
#  8   avg_used_vas_value     4407 non-null   float32
#  9   business_type          4407 non-null   float32
#  10  avg_wallet_bonus       4407 non-null   float32
#  11  avg_active_ads         4407 non-null   float32
#  12  avg_new_ads            4407 non-null   float32
#  13  avg_email_replies      4407 non-null   float32
# ...

# %%
df.describe()
# Out:
#             user_id   account_id  max_return_days  average_return_days  \
# count  4.407000e+03  4400.000000      4407.000000          4407.000000
# mean   4.106655e+09   506.553864        22.335602             7.171576
# std    6.794948e+09   326.072754        43.591244            19.209093
# min    4.100390e+05   111.000000         1.000000             0.500000
# 25%    6.184510e+08   226.000000         1.000000             1.000000
# 50%    7.296627e+08   493.000000         2.000000             1.076923
# 75%    7.292936e+09  1005.000000        30.000000             5.666667
# max    7.356030e+10  1017.000000       354.000000           354.000000
#
#        customer_since_months  total_revenue  average_revenue  avg_vas_count  \
# count            4407.000000    4407.000000      4407.000000    4407.000000
# mean                9.874064     194.130356        16.942616       3.249388
# std                 5.169640    1548.361572       128.268829       5.509869
# ...

# %%
df[['max_return_days','average_return_days']].plot.box(vert = False, grid = True)

# %%
df[['total_revenue','average_revenue']].plot.box(vert = False, grid = True)

# %%
df[['total_revenue','average_revenue']].plot.box(vert = False, grid = True)

# %%
df['customer_since_months'].plot.hist(bins=5,title = 'Customer Since Months')

# %%
counts=df['business_type'].value_counts()
print(counts)
# Out:
# 0.0    3482
# 1.0     458
# 3.0     199
# 5.0     165
# 4.0      54
# 2.0      49
# Name: business_type, dtype: int64

# %%
count=[3482,458,49,199,54,165]
index=[0,1,2,3,4,5]
plt.bar(index,count)
plt.title("Business Type Count")
plt.show()

# %%
df[['avg_email_replies','avg_call_replies','avg_sms_replies']].plot.box(vert = False, grid = True)

# %%
df[['avg_active_ads','avg_new_ads']].plot.box(vert = False, grid = True)

# %%
df['avg_wallet_bonus'].plot.hist(bins=5,title = 'Wallet Bonus')

# %%
plt.scatter(df['business_type'],df['avg_wallet_bonus'])
plt.title("Wallet Bonus per Business Type")
# Out:
# Text(0.5, 1.0, 'Wallet Bonus per Business Type')

# %%
plt.scatter(df['business_type'],df['avg_active_ads'],c='red')
plt.title("Avg Active Ads per Busines")
plt.show()
plt.scatter(df['business_type'],df['avg_new_ads'],c='green')
plt.title("Avg New Ads per Busines")
plt.show()

# %%
df=df.drop(['user_id','account_id'],axis=1)

# %%
df=df.to_numpy()

# %%
df.shape
# Out:
# (4407, 15)

# %%
training=df[0:4000]
testing=df[4000:]

# %%
train_features=training[:,0:-1]
train_labels=training[:,-1]
test_features=testing[:,0:-1]
test_labels=testing[:,-1]

# %%
print(train_features.shape,train_labels.shape)
print(test_features.shape,test_labels.shape)
print(train_features[0].shape)
# Out:
# (4000, 14) (4000,)
# (407, 14) (407,)
# (14,)

# %%
model=tf.keras.Sequential([
tf.keras.layers.Dense(14, activation='relu', input_shape=(14,)),
tf.keras.layers.Dense(32, activation='relu'),
tf.keras.layers.Dropout(0.5),
tf.keras.layers.Dense(16, activation='relu'),
tf.keras.layers.Dropout(0.3),
tf.keras.layers.Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics='acc')

# %%
history=model.fit(train_features,train_labels,
                  validation_data=(test_features,test_labels),
          epochs=100)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 1s 9ms/step - loss: 9.4135 - acc: 0.6630 - val_loss: 2.0486 - val_acc: 0.8108
# Epoch 2/100
# 125/125 [==============================] - 1s 5ms/step - loss: 2.5971 - acc: 0.8345 - val_loss: 1.7001 - val_acc: 0.8133
# Epoch 3/100
# 125/125 [==============================] - 1s 6ms/step - loss: 1.6923 - acc: 0.8342 - val_loss: 1.3299 - val_acc: 0.8034
# Epoch 4/100
# 125/125 [==============================] - 1s 5ms/step - loss: 1.2805 - acc: 0.8468 - val_loss: 0.9211 - val_acc: 0.8108
# Epoch 5/100
# 125/125 [==============================] - 1s 6ms/step - loss: 1.0486 - acc: 0.8575 - val_loss: 0.7539 - val_acc: 0.8059
# Epoch 6/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.7541 - acc: 0.8705 - val_loss: 0.6561 - val_acc: 0.8108
# Epoch 7/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.6412 - acc: 0.8677 - val_loss: 0.6001 - val_acc: 0.8108
# Epoch 8/100
# ...

# %%
import matplotlib.pyplot as plt


plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
ev=[[1,1.000000,14,0.0,0.0,6.307692,176.153846,0,1481.0,409.538462,80.7692318,7.461538,57.615385,0.000000]]
arr=np.array(ev)
print(arr.shape)
result=model.predict(arr)
print(result.shape)
print(result)
# Out:
# (1, 14)
# (1, 1)
# [[0.06966955]]

# %%
pip install shap

# %%
import shap
explainer = shap.TreeExplainer(my_model)
shap_values = explainer.shap_values(arr)
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_values[1], arr)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
my_model = RandomForestClassifier(random_state=0).fit(train_features, train_labels)
